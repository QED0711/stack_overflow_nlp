# %%
import numpy as np
import pandas as pd

# %%
so_data = pd.read_csv("../data/raw/stack_overflow_parsed_text.zip")
label_data = pd.read_csv("../data/raw/stack_overfow_tags.zip")

# %%
so_data.head()
# Out:
#          id                                               body  \
# 0  11227809  <p>Here is a piece of C++ code that seems very...
# 1    927358  <p>I committed the wrong files to Git.</p> <p>...
# 2    179123  <p>I wrote the wrong thing in a commit message...
# 3   2003505  <p>I want to delete a branch both locally and ...
# 4    477816  <p>I've been messing around with <a href= http...
#
#                                                 tags  \
# 0  java|c++|performance|optimization|branch-predi...
# 1                git|git-commit|git-reset|git-revert
# 2           git|git-commit|git-rewrite-history|amend
# 3                   git|github|git-branch|git-remote
# 4                                  json|content-type
#
#                                                 text
# 0  \n\nHere is a piece of C++ code that seems ver...
# 1  \n\nI committed the wrong files to Git.\n\nHow...
# 2  \n\nI wrote the wrong thing in a commit messag...
# 3  \n\nI want to delete a branch both locally and...
# 4  \n\nI've been messing around with JSON for som...

# %%
label_data.head(10)
# Out:
#           tag  count
# 0        java   7562
# 1          c#   7166
# 2  javascript   6963
# 3     android   5729
# 4      python   5093
# 5         c++   3961
# 6        .net   3360
# 7      jquery   3306
# 8        html   2771
# 9         php   2726

# %% [markdown]
# ## Select the top tags that we want for classifiers and make target
#
# In this case, we are looking at the most common tags, and selecting from those just languages.
#
# With our tags, loop through each row and apply a target if a label matches part of the tag.

# %%
def make_target(tag):
    current_label = ""
    top_5 = ["java", "c#", "javascript", "python", "c++"]
    
    for label in top_5:
        if label in tag:
            if current_label == "":
                current_label += label
            else: 
                current_label += "|" + label
    
    if current_label == "":
        return np.NaN
    
    if current_label == "java|javascript":
        return "javascript"
    
    return current_label

so_data["target"] = so_data.tags.apply(make_target)

# %%
so_data.dropna(inplace=True)

# %%
so_data
# Out:
#              id                                               body  \
# 0      11227809  <p>Here is a piece of C++ code that seems very...
# 6        111102  <p>How would you explain JavaScript closures t...
# 7       1642028  <p>After reading <a href= http://groups.google...
# 8        503093  <p>How can I redirect the user from one page t...
# 10       231767  <p>What is the use of the <code>yield</code> k...
# 12      1789945  <p>How can I check if one string contains anot...
# 13      1335851  <p>Recently I ran some of my JavaScript code t...
# 14       178325  <p>In jQuery it is possible to toggle the visi...
# 15     14994391  <p>Suppose I'm familiar with developing client...
# 16      6841333  <p>If I run the following program which parses...
# 17       388242  <p>This question attempts to collect the few p...
# 19       336859  <p>I've recently started maintaining someone e...
# 23       359494  <p>I'm using <a href= http://en.wikipedia.org/...
# 27         7074  <p>In C# what is the difference between <code>...
# 30        40480  <p>I always thought Java was <strong>pass-by-r...
# 34       100003  <p>What are metaclasses? What do you use them ...
# 35      5767325  <p>I have an array of integers which I'm using...
# 36       122102  <p>What is the most efficient way to clone a J...
# 38       208105  <p>Say I create an object as follows:</p> <pre...
# 44       134845  <p>The following are two methods of building a...
# 45       901115  <p>Is there a plugin-less way of retrieving <a...
# 46       950087  <p>Is there something in JavaScript similar to...
# 49       901712  <p>I need to check the <code>checked</code> pr...
# 50      8710619  <p>Until today I thought that for example:</p>...
# 51       426258  <p>I'd like to do something like this to tick ...
# 53       271526  <p>The idiom I use the most when programming i...
# 56        82831  <p>How do I check whether a file exists using ...
# 58      9329446  <p>How can I loop through all the objects in a...
# 62       394809  <p>If not is it possible to simulate one using...
# 66       221294  <p>How can I get a timestamp in JavaScript?</p...
# ...         ...                                                ...
# 80214   3454526  <p>Let's say I have a large HTML file with dif...
# 80216  20837856  <p>I'm trying to POST a <code>List</code> of c...
# 80217   8811735  <p>I am attempting to create a Backbone.js vie...
# 80219   5322344  <h3>JavaScript:</h3> <pre><code>$(document).re...
# 80222   3005219  <p>I recently learned how to rotate a BitmapIm...
# 80225   3560393  <p>i want to take a string and check the first...
# 80227  10619596  <h1>How can I make a data binding update as so...
# 80228   7261707  <p>I am trying to compile a simple VS program ...
# 80229   8686331  <p>I wonder why 'Y' returns 2012 while 'y' ret...
# 80230  18421523  <p>I want to start using AngularJs and Java Sp...
# 80234   3504396  <p>are there any interpretors available online...
# 80242    301442  <p>I want to create a compiled JavaScript file...
# 80244   4475014  <p>I'd like to produce a warning message when ...
# 80245   7502905  <p>We hit an extremely surprising exception to...
# 80248   1073846  <p>I've been looking at the Moq documentation ...
# 80255   3869830  <p>What is difference between our usual pointe...
# 80257   2031217  <p>I am trying to write a function to determin...
# 80259  10625716  <p>In what cases should we include <strong>cas...
# 80260  32636110  <p>Consider a loop like this:</p> <pre><code>f...
# 80263    148879  <p>My .NET application fails when run from a n...
# 80265     57020  <p>Was considering the <code>System.Collection...
# 80269   2574080  <p>I have a list containing version strings su...
# 80270  14160498  <p>I have multiple elements with the attribute...
# 80272  20241765  <p>So I am fairly new to Java and I am trying ...
# 80274   4053265  <p>I have several launch configurations in ecl...
# 80276    833102  <p>[<strong>Update</strong>: <em>Format specif...
# 80278   8744162  <p>From what I understand when a JSF action re...
# 80280   7576525  <p>I found the very useful syntax</p> <pre><co...
# 80281   8601831  <p>I heard that using <code>System.out.println...
# 80282  15322556  <p>Can I in D3.JS remove an attribute? I've ad...
#
#                                                     tags  \
# 0      java|c++|performance|optimization|branch-predi...
# 6                              javascript|scope|closures
# 7      c++|c|operators|code-formatting|standards-comp...
# 8                             javascript|jquery|redirect
# 10             python|iterator|generator|yield|coroutine
# 12                     javascript|string|string-matching
# 13                   javascript|syntax|jslint|use-strict
# 14                      javascript|jquery|dom|visibility
# 15                    javascript|jquery|angularjs|design
# 16                                    java|date|timezone
# 17                                           c++|c++-faq
# 19                     javascript|function|syntax|idioms
# 23     javascript|operators|equality|equality-operato...
# 27                                             c#|string
# 30     java|methods|parameter-passing|pass-by-referen...
# 34                 python|oop|metaclass|python-datamodel
# 35                                     javascript|arrays
# 36                               javascript|object|clone
# 38                          javascript|object-properties
# 44         javascript|html|performance|optimization|href
# 45                   javascript|url|plugins|query-string
# 46                        javascript|file|import|include
# 49                            javascript|jquery|checkbox
# 50     java|casting|operators|variable-assignment|ass...
# 51           javascript|jquery|checkbox|selected|checked
# 53                        java|nullpointerexception|null
# 56                               python|file|filesystems
# 58             javascript|arrays|loops|foreach|iteration
# 62     python|operators|ternary-operator|conditional-...
# 66     javascript|date|datetime|timestamp|unix-timestamp
# ...                                                  ...
# 80214                   javascript|jquery|html|xml|xpath
# 80216                java|spring|jackson|jax-rs|resteasy
# 80217  javascript|backbone.js|coffeescript|twitter-bo...
# 80219                                  javascript|jquery
# 80222                                       c#|wpf|image
# 80225                           c#|asp.net|visual-studio
# 80227                   c#|wpf|xaml|data-binding|textbox
# 80228               c++|visual-studio|visual-studio-2010
# 80229                         java|date|simpledateformat
# 80230                      java|eclipse|spring|angularjs
# 80234                                               java
# 80242                  javascript|batch-file|compression
# 80244                                            c#|.net
# 80245      java|synchronization|illegalmonitorstateexcep
# 80248                              c#|mocking|lambda|moq
# 80255                                     c++|c|pointers
# 80257                               c#|comparison|bitmap
# 80259                            c++|header-files|assert
# 80260                              c#|integer-arithmetic
# 80263  c#|.net|networking|securityexception|permissio...
# 80265                            c#|.net-3.5|collections
# 80269                                             python
# 80270                                  javascript|jquery
# 80272  java|android|android-studio|gradle|android-gradle
# 80274                     java|eclipse|run-configuration
# 80276                             c#|datetime|format|utc
# 80278                                java|jsf|navigation
# 80280                              python|stdin|argparse
# 80281                               java|logging|backend
# 80282                    javascript|dom|attributes|d3.js
#
#                                                     text      target
# 0      \n\nHere is a piece of C++ code that seems ver...    java|c++
# 6      \n\nHow would you explain JavaScript closures ...  javascript
# 7      \n\nAfter reading Hidden Features and Dark Cor...         c++
# 8      \n\nHow can I redirect the user from one page ...  javascript
# 10     \n\nWhat is the use of the `yield` keyword in ...      python
# 12     \n\nHow can I check if one string contains ano...  javascript
# 13     \n\nRecently I ran some of my JavaScript code ...  javascript
# 14     \n\nIn jQuery it is possible to toggle the vis...  javascript
# 15     \n\nSuppose I'm familiar with developing clien...  javascript
# 16     \n\nIf I run the following program which parse...        java
# 17     \n\nThis question attempts to collect the few ...         c++
# 19     \n\nI've recently started maintaining someone ...  javascript
# 23     \n\nI'm using JSLint to go through JavaScript ...  javascript
# 27     \n\nIn C# what is the difference between `Stri...          c#
# 30     \n\nI always thought Java was **pass-by-refere...        java
# 34     \n\nWhat are metaclasses? What do you use them...      python
# 35     \n\nI have an array of integers which I'm usin...  javascript
# 36     \n\nWhat is the most efficient way to clone a ...  javascript
# 38     \n\nSay I create an object as follows:\n\n    ...  javascript
# 44     \n\nThe following are two methods of building ...  javascript
# 45     \n\nIs there a plugin-less way of retrieving q...  javascript
# 46     \n\nIs there something in JavaScript similar t...  javascript
# 49     \n\nI need to check the `checked` property of ...  javascript
# 50     \n\nUntil today I thought that for example:\n\...        java
# 51     \n\nI'd like to do something like this to tick...  javascript
# 53     \n\nThe idiom I use the most when programming ...        java
# 56     \n\nHow do I check whether a file exists using...      python
# 58     \n\nHow can I loop through all the objects in ...  javascript
# 62     \n\nIf not is it possible to simulate one usin...      python
# 66     \n\nHow can I get a timestamp in JavaScript?\n...  javascript
# ...                                                  ...         ...
# 80214  \n\nLet's say I have a large HTML file with di...  javascript
# 80216  \n\nI'm trying to POST a `List` of custom obje...        java
# 80217  \n\nI am attempting to create a Backbone.js vi...  javascript
# 80219  \n\n### JavaScript:\n\n    \n    \n    $(docum...  javascript
# 80222  \n\nI recently learned how to rotate a BitmapI...          c#
# 80225  \n\ni want to take a string and check the firs...          c#
# 80227  \n\n# How can I make a data binding update as ...          c#
# 80228  \n\nI am trying to compile a simple VS program...         c++
# 80229  \n\nI wonder why 'Y' returns 2012 while 'y' re...        java
# 80230  \n\nI want to start using AngularJs and Java S...        java
# 80234  \n\nare there any interpretors available onlin...        java
# 80242  \n\nI want to create a compiled JavaScript fil...  javascript
# 80244  \n\nI'd like to produce a warning message when...          c#
# 80245  \n\nWe hit an extremely surprising exception t...        java
# 80248  \n\nI've been looking at the Moq documentation...          c#
# 80255  \n\nWhat is difference between our usual point...         c++
# 80257  \n\nI am trying to write a function to determi...          c#
# 80259  \n\nIn what cases should we include **cassert*...         c++
# 80260  \n\nConsider a loop like this:\n\n    \n    \n...          c#
# 80263  \n\nMy .NET application fails when run from a ...          c#
# 80265  \n\nWas considering the `System.Collections.Ob...          c#
# 80269  \n\nI have a list containing version strings s...      python
# 80270  \n\nI have multiple elements with the attribut...  javascript
# 80272  \n\nSo I am fairly new to Java and I am trying...        java
# 80274  \n\nI have several launch configurations in ec...        java
# 80276  \n\n[ **Update** : _Format specifiers are not ...          c#
# 80278  \n\nFrom what I understand when a JSF action r...        java
# 80280  \n\nI found the very useful syntax\n\n    \n  ...      python
# 80281  \n\nI heard that using `System.out.println` fo...        java
# 80282  \n\nCan I in D3.JS remove an attribute? I've a...  javascript
#
# [30685 rows x 5 columns]

# %% [markdown]
# ## check to see where any overlap is
#
# We want to make sure that there is no overlap in our tags as that could throw off our results.

# %%
so_data.target.value_counts()
# Out:
# java                      7470
# c#                        6986
# javascript                6944
# python                    5025
# c++                       3877
# java|c#                    100
# c#|c++                      52
# java|c++                    51
# java|c#|javascript          45
# java|python                 40
# python|c++                  34
# java|javascript|python      32
# java|c#|c++                 11
# c#|python                   10
# java|javascript|c++          4
# java|c#|python               3
# java|python|c++              1
# Name: target, dtype: int64

# %% [markdown]
# We will drop any of the overlapping targets listed above because we will still have enough data for our model training.

# %%
so_data.target = so_data.target.apply(lambda label: np.NaN if "|" in label else label)

# %%
so_data.dropna(inplace=True)

# %%
so_data.target.value_counts(normalize=True)
# Out:
# java          0.246518
# c#            0.230546
# javascript    0.229160
# python        0.165831
# c++           0.127945
# Name: target, dtype: float64

# %% [markdown]
# ## Save our labeled data

# %%
so_data.to_csv("../data/interum/stack_overflow_with_targets.csv", index=False)
